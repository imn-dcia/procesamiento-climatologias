# %% [markdown]
# # Procesamiento de climatologías - agrupación por año

# %% [markdown]
# Este _notebook_ contiene programas en Python para el procesamiento de climatologías, agrupándolas por año. Una climatología se define como un conjunto de medidas estadísticas que resumen series temporales de variables climáticas como precipitación, temperatura, radiación solar y velocidad del viento, entre otras.

# %% [markdown]
# **Bibliotecas**

# %%
import os

import rasterio

from shapely.geometry import Point

import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## Entrada

# %%
# Directorio de datos de entrada
INPUT_DATA_DIR = "/home/mfvargas/procesamiento-climatologias-datos/chelsa-recortados-cr"

# Directorio de datos de salida
OUTPUT_DATA_DIR = "/home/mfvargas/procesamiento-climatologias-datos/chelsa-recortados-cr-agrupados-anio"

# Año inicial
START_YEAR = 1981

# Año final
END_YEAR = 2010

# Valor de NO DATA
NO_DATA_VALUE = 65535

# %% [markdown]
# ## Procesamiento

# %%
for year in range(START_YEAR, END_YEAR + 1):
    print("year:", year)

    # DataFrame
    centros_gdf = gpd.GeoDataFrame(columns=['geometry', 'x', 'y'], crs={"init": "epsg:4326"})

    # Contador de archivos
    f = 0

    # Recorrido de los archivos del directorio de entrada
    files = os.listdir(INPUT_DATA_DIR)
    files.sort()
    for file in files:
        anio = file[12:16]
        mes = file[17:19]

        if anio != str(year):
            continue
            
        #if mes not in ('01', '02'):
        #    continue            

        print("Año:", anio, "Mes:", mes)
        centros_gdf['c_' + anio + '_' + mes] = 65535

        dataset = rasterio.open(INPUT_DATA_DIR + "/" + file)
        print("Archivo:", file, "Ancho:", dataset.width, "Largo:", dataset.height)

        # Recuperación de los valores de la banda 1 en un arreglo
        band = dataset.read(1)

        # Recorrido de las filas y columnas de la banda
        i = 0
        t = 0
        for row in band:
            # print("i:", i)
            j = 0
            for value in row:
                if value != NO_DATA_VALUE:
                    # coordinates = transform.xy(dataset.transform, j, i, offset='center')                    
                    # coordinates = dataset.transform * (j, i)
                    coordinates = dataset.xy(i, j)
                    # print(coordinates)
                    x = coordinates[0]
                    y = coordinates[1]
                    point = Point(coordinates)
                    # print(t, i, j, x, y, point, value)
                    if (f == 0):
                        centros_gdf.loc[t] = [point] + [x] + [y] + [value]
                    else:
                        centros_gdf.loc[[t], ['c_' + anio + '_' + mes]] = value
                    t += 1
                j += 1

            i += 1
        f += 1

    # Columna de la suma
    centros_gdf['suma'] = centros_gdf.iloc[:,3:].sum(axis=1)    

    # Columna del promedio
    centros_gdf['promedio'] = centros_gdf.iloc[:,3:(len(centros_gdf.columns)-1)].mean(axis=1)
    
    # Archivo CSV de salida
    centros_gdf.to_file(OUTPUT_DATA_DIR + "/" + "CHELSA_"+str(year)+".csv", driver="CSV")
    
    # Archivo SHP de salida
    centros_gdf.to_file(OUTPUT_DATA_DIR + "/" + "CHELSA_"+str(year)+".shp")
# Out:
# year: 1981
# Año: 1981 Mes: 01
# Archivo: CHELSA_prec_1981_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 02
# Archivo: CHELSA_prec_1981_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 03
# Archivo: CHELSA_prec_1981_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 04
# Archivo: CHELSA_prec_1981_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 05
# Archivo: CHELSA_prec_1981_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 06
# Archivo: CHELSA_prec_1981_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 07
# Archivo: CHELSA_prec_1981_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 08
# Archivo: CHELSA_prec_1981_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 09
# Archivo: CHELSA_prec_1981_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 10
# Archivo: CHELSA_prec_1981_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 11
# Archivo: CHELSA_prec_1981_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1981 Mes: 12
# Archivo: CHELSA_prec_1981_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1982
# Año: 1982 Mes: 01
# Archivo: CHELSA_prec_1982_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 02
# Archivo: CHELSA_prec_1982_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 03
# Archivo: CHELSA_prec_1982_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 04
# Archivo: CHELSA_prec_1982_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 05
# Archivo: CHELSA_prec_1982_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 06
# Archivo: CHELSA_prec_1982_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 07
# Archivo: CHELSA_prec_1982_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 08
# Archivo: CHELSA_prec_1982_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 09
# Archivo: CHELSA_prec_1982_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 10
# Archivo: CHELSA_prec_1982_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 11
# Archivo: CHELSA_prec_1982_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1982 Mes: 12
# Archivo: CHELSA_prec_1982_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1983
# Año: 1983 Mes: 01
# Archivo: CHELSA_prec_1983_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 02
# Archivo: CHELSA_prec_1983_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 03
# Archivo: CHELSA_prec_1983_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 04
# Archivo: CHELSA_prec_1983_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 05
# Archivo: CHELSA_prec_1983_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 06
# Archivo: CHELSA_prec_1983_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 07
# Archivo: CHELSA_prec_1983_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 08
# Archivo: CHELSA_prec_1983_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 09
# Archivo: CHELSA_prec_1983_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 10
# Archivo: CHELSA_prec_1983_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 11
# Archivo: CHELSA_prec_1983_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1983 Mes: 12
# Archivo: CHELSA_prec_1983_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1984
# Año: 1984 Mes: 01
# Archivo: CHELSA_prec_1984_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 02
# Archivo: CHELSA_prec_1984_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 03
# Archivo: CHELSA_prec_1984_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 04
# Archivo: CHELSA_prec_1984_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 05
# Archivo: CHELSA_prec_1984_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 06
# Archivo: CHELSA_prec_1984_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 07
# Archivo: CHELSA_prec_1984_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 08
# Archivo: CHELSA_prec_1984_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 09
# Archivo: CHELSA_prec_1984_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 10
# Archivo: CHELSA_prec_1984_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 11
# Archivo: CHELSA_prec_1984_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1984 Mes: 12
# Archivo: CHELSA_prec_1984_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1985
# Año: 1985 Mes: 01
# Archivo: CHELSA_prec_1985_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 02
# Archivo: CHELSA_prec_1985_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 03
# Archivo: CHELSA_prec_1985_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 04
# Archivo: CHELSA_prec_1985_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 05
# Archivo: CHELSA_prec_1985_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 06
# Archivo: CHELSA_prec_1985_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 07
# Archivo: CHELSA_prec_1985_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 08
# Archivo: CHELSA_prec_1985_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 09
# Archivo: CHELSA_prec_1985_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 10
# Archivo: CHELSA_prec_1985_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 11
# Archivo: CHELSA_prec_1985_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1985 Mes: 12
# Archivo: CHELSA_prec_1985_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1986
# Año: 1986 Mes: 01
# Archivo: CHELSA_prec_1986_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 02
# Archivo: CHELSA_prec_1986_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 03
# Archivo: CHELSA_prec_1986_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 04
# Archivo: CHELSA_prec_1986_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 05
# Archivo: CHELSA_prec_1986_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 06
# Archivo: CHELSA_prec_1986_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 07
# Archivo: CHELSA_prec_1986_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 08
# Archivo: CHELSA_prec_1986_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 09
# Archivo: CHELSA_prec_1986_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 10
# Archivo: CHELSA_prec_1986_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 11
# Archivo: CHELSA_prec_1986_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1986 Mes: 12
# Archivo: CHELSA_prec_1986_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1987
# Año: 1987 Mes: 01
# Archivo: CHELSA_prec_1987_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 02
# Archivo: CHELSA_prec_1987_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 03
# Archivo: CHELSA_prec_1987_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 04
# Archivo: CHELSA_prec_1987_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 05
# Archivo: CHELSA_prec_1987_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 06
# Archivo: CHELSA_prec_1987_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 07
# Archivo: CHELSA_prec_1987_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 08
# Archivo: CHELSA_prec_1987_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 09
# Archivo: CHELSA_prec_1987_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 10
# Archivo: CHELSA_prec_1987_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 11
# Archivo: CHELSA_prec_1987_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1987 Mes: 12
# Archivo: CHELSA_prec_1987_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1988
# Año: 1988 Mes: 01
# Archivo: CHELSA_prec_1988_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 02
# Archivo: CHELSA_prec_1988_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 03
# Archivo: CHELSA_prec_1988_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 04
# Archivo: CHELSA_prec_1988_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 05
# Archivo: CHELSA_prec_1988_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 06
# Archivo: CHELSA_prec_1988_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 07
# Archivo: CHELSA_prec_1988_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 08
# Archivo: CHELSA_prec_1988_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 09
# Archivo: CHELSA_prec_1988_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 10
# Archivo: CHELSA_prec_1988_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 11
# Archivo: CHELSA_prec_1988_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1988 Mes: 12
# Archivo: CHELSA_prec_1988_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1989
# Año: 1989 Mes: 01
# Archivo: CHELSA_prec_1989_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 02
# Archivo: CHELSA_prec_1989_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 03
# Archivo: CHELSA_prec_1989_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 04
# Archivo: CHELSA_prec_1989_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 05
# Archivo: CHELSA_prec_1989_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 06
# Archivo: CHELSA_prec_1989_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 07
# Archivo: CHELSA_prec_1989_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 08
# Archivo: CHELSA_prec_1989_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 09
# Archivo: CHELSA_prec_1989_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 10
# Archivo: CHELSA_prec_1989_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 11
# Archivo: CHELSA_prec_1989_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1989 Mes: 12
# Archivo: CHELSA_prec_1989_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1990
# Año: 1990 Mes: 01
# Archivo: CHELSA_prec_1990_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 02
# Archivo: CHELSA_prec_1990_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 03
# Archivo: CHELSA_prec_1990_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 04
# Archivo: CHELSA_prec_1990_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 05
# Archivo: CHELSA_prec_1990_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 06
# Archivo: CHELSA_prec_1990_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 07
# Archivo: CHELSA_prec_1990_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 08
# Archivo: CHELSA_prec_1990_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 09
# Archivo: CHELSA_prec_1990_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 10
# Archivo: CHELSA_prec_1990_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 11
# Archivo: CHELSA_prec_1990_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1990 Mes: 12
# Archivo: CHELSA_prec_1990_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1991
# Año: 1991 Mes: 01
# Archivo: CHELSA_prec_1991_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 02
# Archivo: CHELSA_prec_1991_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 03
# Archivo: CHELSA_prec_1991_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 04
# Archivo: CHELSA_prec_1991_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 05
# Archivo: CHELSA_prec_1991_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 06
# Archivo: CHELSA_prec_1991_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 07
# Archivo: CHELSA_prec_1991_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 08
# Archivo: CHELSA_prec_1991_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 09
# Archivo: CHELSA_prec_1991_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 10
# Archivo: CHELSA_prec_1991_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 11
# Archivo: CHELSA_prec_1991_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1991 Mes: 12
# Archivo: CHELSA_prec_1991_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1992
# Año: 1992 Mes: 01
# Archivo: CHELSA_prec_1992_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 02
# Archivo: CHELSA_prec_1992_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 03
# Archivo: CHELSA_prec_1992_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 04
# Archivo: CHELSA_prec_1992_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 05
# Archivo: CHELSA_prec_1992_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 06
# Archivo: CHELSA_prec_1992_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 07
# Archivo: CHELSA_prec_1992_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 08
# Archivo: CHELSA_prec_1992_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 09
# Archivo: CHELSA_prec_1992_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 10
# Archivo: CHELSA_prec_1992_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 11
# Archivo: CHELSA_prec_1992_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1992 Mes: 12
# Archivo: CHELSA_prec_1992_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1993
# Año: 1993 Mes: 01
# Archivo: CHELSA_prec_1993_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 02
# Archivo: CHELSA_prec_1993_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 03
# Archivo: CHELSA_prec_1993_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 04
# Archivo: CHELSA_prec_1993_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 05
# Archivo: CHELSA_prec_1993_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 06
# Archivo: CHELSA_prec_1993_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 07
# Archivo: CHELSA_prec_1993_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 08
# Archivo: CHELSA_prec_1993_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 09
# Archivo: CHELSA_prec_1993_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 10
# Archivo: CHELSA_prec_1993_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 11
# Archivo: CHELSA_prec_1993_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1993 Mes: 12
# Archivo: CHELSA_prec_1993_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1994
# Año: 1994 Mes: 01
# Archivo: CHELSA_prec_1994_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 02
# Archivo: CHELSA_prec_1994_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 03
# Archivo: CHELSA_prec_1994_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 04
# Archivo: CHELSA_prec_1994_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 05
# Archivo: CHELSA_prec_1994_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 06
# Archivo: CHELSA_prec_1994_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 07
# Archivo: CHELSA_prec_1994_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 08
# Archivo: CHELSA_prec_1994_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 09
# Archivo: CHELSA_prec_1994_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 10
# Archivo: CHELSA_prec_1994_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 11
# Archivo: CHELSA_prec_1994_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1994 Mes: 12
# Archivo: CHELSA_prec_1994_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1995
# Año: 1995 Mes: 01
# Archivo: CHELSA_prec_1995_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 02
# Archivo: CHELSA_prec_1995_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 03
# Archivo: CHELSA_prec_1995_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 04
# Archivo: CHELSA_prec_1995_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 05
# Archivo: CHELSA_prec_1995_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 06
# Archivo: CHELSA_prec_1995_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 07
# Archivo: CHELSA_prec_1995_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 08
# Archivo: CHELSA_prec_1995_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 09
# Archivo: CHELSA_prec_1995_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 10
# Archivo: CHELSA_prec_1995_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 11
# Archivo: CHELSA_prec_1995_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1995 Mes: 12
# Archivo: CHELSA_prec_1995_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1996
# Año: 1996 Mes: 01
# Archivo: CHELSA_prec_1996_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 02
# Archivo: CHELSA_prec_1996_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 03
# Archivo: CHELSA_prec_1996_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 04
# Archivo: CHELSA_prec_1996_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 05
# Archivo: CHELSA_prec_1996_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 06
# Archivo: CHELSA_prec_1996_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 07
# Archivo: CHELSA_prec_1996_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 08
# Archivo: CHELSA_prec_1996_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 09
# Archivo: CHELSA_prec_1996_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 10
# Archivo: CHELSA_prec_1996_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 11
# Archivo: CHELSA_prec_1996_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1996 Mes: 12
# Archivo: CHELSA_prec_1996_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1997
# Año: 1997 Mes: 01
# Archivo: CHELSA_prec_1997_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 02
# Archivo: CHELSA_prec_1997_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 03
# Archivo: CHELSA_prec_1997_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 04
# Archivo: CHELSA_prec_1997_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 05
# Archivo: CHELSA_prec_1997_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 06
# Archivo: CHELSA_prec_1997_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 07
# Archivo: CHELSA_prec_1997_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 08
# Archivo: CHELSA_prec_1997_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 09
# Archivo: CHELSA_prec_1997_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 10
# Archivo: CHELSA_prec_1997_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 11
# Archivo: CHELSA_prec_1997_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1997 Mes: 12
# Archivo: CHELSA_prec_1997_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1998
# Año: 1998 Mes: 01
# Archivo: CHELSA_prec_1998_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 02
# Archivo: CHELSA_prec_1998_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 03
# Archivo: CHELSA_prec_1998_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 04
# Archivo: CHELSA_prec_1998_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 05
# Archivo: CHELSA_prec_1998_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 06
# Archivo: CHELSA_prec_1998_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 07
# Archivo: CHELSA_prec_1998_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 08
# Archivo: CHELSA_prec_1998_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 09
# Archivo: CHELSA_prec_1998_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 10
# Archivo: CHELSA_prec_1998_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 11
# Archivo: CHELSA_prec_1998_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1998 Mes: 12
# Archivo: CHELSA_prec_1998_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 1999
# Año: 1999 Mes: 01
# Archivo: CHELSA_prec_1999_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 02
# Archivo: CHELSA_prec_1999_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 03
# Archivo: CHELSA_prec_1999_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 04
# Archivo: CHELSA_prec_1999_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 05
# Archivo: CHELSA_prec_1999_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 06
# Archivo: CHELSA_prec_1999_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 07
# Archivo: CHELSA_prec_1999_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 08
# Archivo: CHELSA_prec_1999_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 09
# Archivo: CHELSA_prec_1999_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 10
# Archivo: CHELSA_prec_1999_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 11
# Archivo: CHELSA_prec_1999_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 1999 Mes: 12
# Archivo: CHELSA_prec_1999_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2000
# Año: 2000 Mes: 01
# Archivo: CHELSA_prec_2000_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 02
# Archivo: CHELSA_prec_2000_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 03
# Archivo: CHELSA_prec_2000_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 04
# Archivo: CHELSA_prec_2000_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 05
# Archivo: CHELSA_prec_2000_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 06
# Archivo: CHELSA_prec_2000_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 07
# Archivo: CHELSA_prec_2000_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 08
# Archivo: CHELSA_prec_2000_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 09
# Archivo: CHELSA_prec_2000_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 10
# Archivo: CHELSA_prec_2000_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 11
# Archivo: CHELSA_prec_2000_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2000 Mes: 12
# Archivo: CHELSA_prec_2000_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2001
# Año: 2001 Mes: 01
# Archivo: CHELSA_prec_2001_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 02
# Archivo: CHELSA_prec_2001_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 03
# Archivo: CHELSA_prec_2001_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 04
# Archivo: CHELSA_prec_2001_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 05
# Archivo: CHELSA_prec_2001_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 06
# Archivo: CHELSA_prec_2001_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 07
# Archivo: CHELSA_prec_2001_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 08
# Archivo: CHELSA_prec_2001_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 09
# Archivo: CHELSA_prec_2001_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 10
# Archivo: CHELSA_prec_2001_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 11
# Archivo: CHELSA_prec_2001_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2001 Mes: 12
# Archivo: CHELSA_prec_2001_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2002
# Año: 2002 Mes: 01
# Archivo: CHELSA_prec_2002_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 02
# Archivo: CHELSA_prec_2002_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 03
# Archivo: CHELSA_prec_2002_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 04
# Archivo: CHELSA_prec_2002_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 05
# Archivo: CHELSA_prec_2002_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 06
# Archivo: CHELSA_prec_2002_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 07
# Archivo: CHELSA_prec_2002_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 08
# Archivo: CHELSA_prec_2002_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 09
# Archivo: CHELSA_prec_2002_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 10
# Archivo: CHELSA_prec_2002_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 11
# Archivo: CHELSA_prec_2002_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2002 Mes: 12
# Archivo: CHELSA_prec_2002_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2003
# Año: 2003 Mes: 01
# Archivo: CHELSA_prec_2003_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 02
# Archivo: CHELSA_prec_2003_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 03
# Archivo: CHELSA_prec_2003_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 04
# Archivo: CHELSA_prec_2003_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 05
# Archivo: CHELSA_prec_2003_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 06
# Archivo: CHELSA_prec_2003_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 07
# Archivo: CHELSA_prec_2003_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 08
# Archivo: CHELSA_prec_2003_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 09
# Archivo: CHELSA_prec_2003_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 10
# Archivo: CHELSA_prec_2003_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 11
# Archivo: CHELSA_prec_2003_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2003 Mes: 12
# Archivo: CHELSA_prec_2003_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2004
# Año: 2004 Mes: 01
# Archivo: CHELSA_prec_2004_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 02
# Archivo: CHELSA_prec_2004_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 03
# Archivo: CHELSA_prec_2004_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 04
# Archivo: CHELSA_prec_2004_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 05
# Archivo: CHELSA_prec_2004_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 06
# Archivo: CHELSA_prec_2004_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 07
# Archivo: CHELSA_prec_2004_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 08
# Archivo: CHELSA_prec_2004_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 09
# Archivo: CHELSA_prec_2004_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 10
# Archivo: CHELSA_prec_2004_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 11
# Archivo: CHELSA_prec_2004_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2004 Mes: 12
# Archivo: CHELSA_prec_2004_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2005
# Año: 2005 Mes: 01
# Archivo: CHELSA_prec_2005_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 02
# Archivo: CHELSA_prec_2005_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 03
# Archivo: CHELSA_prec_2005_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 04
# Archivo: CHELSA_prec_2005_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 05
# Archivo: CHELSA_prec_2005_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 06
# Archivo: CHELSA_prec_2005_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 07
# Archivo: CHELSA_prec_2005_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 08
# Archivo: CHELSA_prec_2005_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 09
# Archivo: CHELSA_prec_2005_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 10
# Archivo: CHELSA_prec_2005_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 11
# Archivo: CHELSA_prec_2005_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2005 Mes: 12
# Archivo: CHELSA_prec_2005_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2006
# Año: 2006 Mes: 01
# Archivo: CHELSA_prec_2006_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 02
# Archivo: CHELSA_prec_2006_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 03
# Archivo: CHELSA_prec_2006_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 04
# Archivo: CHELSA_prec_2006_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 05
# Archivo: CHELSA_prec_2006_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 06
# Archivo: CHELSA_prec_2006_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 07
# Archivo: CHELSA_prec_2006_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 08
# Archivo: CHELSA_prec_2006_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 09
# Archivo: CHELSA_prec_2006_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 10
# Archivo: CHELSA_prec_2006_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 11
# Archivo: CHELSA_prec_2006_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2006 Mes: 12
# Archivo: CHELSA_prec_2006_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2007
# Año: 2007 Mes: 01
# Archivo: CHELSA_prec_2007_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 02
# Archivo: CHELSA_prec_2007_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 03
# Archivo: CHELSA_prec_2007_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 04
# Archivo: CHELSA_prec_2007_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 05
# Archivo: CHELSA_prec_2007_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 06
# Archivo: CHELSA_prec_2007_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 07
# Archivo: CHELSA_prec_2007_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 08
# Archivo: CHELSA_prec_2007_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 09
# Archivo: CHELSA_prec_2007_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 10
# Archivo: CHELSA_prec_2007_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 11
# Archivo: CHELSA_prec_2007_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2007 Mes: 12
# Archivo: CHELSA_prec_2007_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2008
# Año: 2008 Mes: 01
# Archivo: CHELSA_prec_2008_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 02
# Archivo: CHELSA_prec_2008_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 03
# Archivo: CHELSA_prec_2008_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 04
# Archivo: CHELSA_prec_2008_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 05
# Archivo: CHELSA_prec_2008_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 06
# Archivo: CHELSA_prec_2008_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 07
# Archivo: CHELSA_prec_2008_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 08
# Archivo: CHELSA_prec_2008_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 09
# Archivo: CHELSA_prec_2008_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 10
# Archivo: CHELSA_prec_2008_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 11
# Archivo: CHELSA_prec_2008_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2008 Mes: 12
# Archivo: CHELSA_prec_2008_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2009
# Año: 2009 Mes: 01
# Archivo: CHELSA_prec_2009_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 02
# Archivo: CHELSA_prec_2009_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 03
# Archivo: CHELSA_prec_2009_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 04
# Archivo: CHELSA_prec_2009_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 05
# Archivo: CHELSA_prec_2009_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 06
# Archivo: CHELSA_prec_2009_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 07
# Archivo: CHELSA_prec_2009_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 08
# Archivo: CHELSA_prec_2009_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 09
# Archivo: CHELSA_prec_2009_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 10
# Archivo: CHELSA_prec_2009_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 11
# Archivo: CHELSA_prec_2009_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2009 Mes: 12
# Archivo: CHELSA_prec_2009_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# year: 2010
# Año: 2010 Mes: 01
# Archivo: CHELSA_prec_2010_01_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 02
# Archivo: CHELSA_prec_2010_02_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 03
# Archivo: CHELSA_prec_2010_03_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 04
# Archivo: CHELSA_prec_2010_04_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 05
# Archivo: CHELSA_prec_2010_05_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 06
# Archivo: CHELSA_prec_2010_06_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 07
# Archivo: CHELSA_prec_2010_07_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 08
# Archivo: CHELSA_prec_2010_08_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 09
# Archivo: CHELSA_prec_2010_09_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 10
# Archivo: CHELSA_prec_2010_10_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 11
# Archivo: CHELSA_prec_2010_11_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
# Año: 2010 Mes: 12
# Archivo: CHELSA_prec_2010_12_V1.2.1_recortado.tiff Ancho: 411 Largo: 382
